# %%
import json
import re
from pathlib import Path

path = Path('../data/dinoDataBase.json')
obj = json.loads(path.read_text(encoding='utf-8'))
pattern = re.compile(r'^\D*([0-9\.]+)\D*$')
changed = []
for dino, data in obj.items():
    stats = data.get('stats', {})
    for key in ['price', 'skin1', 'skin2', 'fotinha', 'cormoeda', 'corgema']:
        if key in stats and isinstance(stats[key], str):
            value = stats[key]
            if value in ('N/A', '-', 'free'):
                continue
            if value.isdigit():
                continue
            m = pattern.match(value)
            if m:
                new = m.group(1).replace('.', '')
                if new != value:
                    stats[key] = new
                    changed.append((dino, key, value, new))

if changed:
    path.write_text(json.dumps(obj, indent=2, ensure_ascii=False), encoding='utf-8')
    print('Updated', len(changed), 'fields')
    for c in changed[:50]:
        print(c)
else:
    print('No changes made')
# Out:
# Updated 22 fields
# ('Pachycephalosaurus', 'fotinha', '5.000', '5000')
# ('Guanlong', 'fotinha', '3.000', '3000')
# ('Barbaridactylus', 'fotinha', '18.000', '18000')
# ('Psittacosaurus', 'fotinha', '70g', '70')
# ('Quetzalcoatlus', 'fotinha', '15.000', '15000')
# ('Austroraptor', 'fotinha', '12.000', '12000')
# ('Dilophosaurus', 'fotinha', '120g', '120')
# ('Concavenator', 'fotinha', '150g', '150')
# ('Fasolasuchus', 'fotinha', '15.000', '15000')
# ('Kentrosaurus', 'fotinha', '10.000', '10000')
# ('Ceratosaurus', 'fotinha', '30.000', '30000')
# ('Carnotaurus', 'fotinha', '150g', '150')
# ('Gigantoraptor', 'fotinha', '15.000', '15000')
# ('Styracosaurus', 'fotinha', '10.000', '10000')
# ('Tarchia', 'fotinha', '8.000', '8000')
# ('Pachyrhinosaurus', 'fotinha', '7.000', '7000')
# ('Stegosaurus', 'fotinha', '60g', '60')
# ('Suchomimus', 'fotinha', '15.000', '15000')
# ('Sarcosuchus', 'fotinha', '250g', '250')
# ('Spinosaurus', 'fotinha', '22.000', '22000')
# ('Triceratops', 'fotinha', '20.000', '20000')
# ('Tyrannosaurus', 'fotinha', '200g', '200')
